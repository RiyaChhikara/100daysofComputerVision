# %% [markdown]
# # Introduction to OpenCV

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/image.jpg')

# %%
# Extract height and width of the image
h,w = image.shape[:2]
print(f"Height: {h}, Width: {w}")
# Out:
# Height: 1960, Width: 1308

# %%
# Extract RGB values
(B, G, R) = image[100, 100]
print(f"R: {R}, G: {G}, B: {B}")
# Out:
# R: 212, G: 212, B: 212

# %%
# We will calculate the region of interest
# by slicing the pixels of the image
roi = image[500: 1000, 500: 1000]
roi
# Out:
# array([[[ 40,  46,  59],
#         [ 40,  46,  59],
#         [ 38,  44,  57],
#         ...,
#         [ 15,  19,  30],
#         [ 92,  98, 111],
#         [132, 140, 153]],
#
#        [[ 45,  50,  65],
#         [ 44,  50,  63],
#         [ 42,  47,  62],
#         ...,
#         [ 48,  52,  63],
#         [  2,   8,  21],
#         [ 51,  59,  72]],
#
#        [[ 49,  56,  73],
#         [ 46,  53,  68],
#         [ 44,  51,  68],
#         ...,
#         [ 46,  48,  59],
#         [ 38,  41,  55],
#         [ 36,  42,  55]],
#
#        ...,
#
#        [[154, 181, 245],
#         [154, 181, 245],
#         [153, 180, 244],
#         ...,
#         [237, 239, 250],
#         [239, 240, 254],
#         [240, 241, 255]],
#
#        [[153, 180, 244],
#         [153, 180, 244],
#         [151, 178, 242],
#         ...,
#         [237, 238, 252],
#         [235, 238, 252],
#         [235, 238, 252]],
#
#        [[151, 178, 242],
#         [151, 178, 242],
#         [149, 176, 240],
# ...

# %% [markdown]
# # Detect object using Haar Cascade
#
# Haar Cascade is a machine learning-based approach where a lot of positive and negative images are used to train the classifier.
#
#
# Positive images – These images contain the images that we want our classifier to identify.
#
# Negative Images – Images of everything else, which do not contain the object we want to detect.

# %%
img = cv2.imread('/content/stop_sign.jpg')

# OpenCV opens images as BRG
# but we want it as RGB and
# we also need a grayscale
# version
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()

# %%
stop_data = cv2.CascadeClassifier('/content/stop_data.xml')
found = stop_data.detectMultiScale(img_gray,
                                   minSize = (20,20))

# Don't do anything if there's no sign
amount_found = len(found)

if amount_found !=0:
     # There may be more than one
     # sign in the image
  for (x, y, width, height) in found:
      # We draw a green rectangle around every recognized sign
    cv2.rectangle(img_rgb, (x,y),
                  (x + height, y + width),
                  (0, 255, 0), 5)

# %%
# Creates the environment of the picture and shows it
plt.subplot(1, 1, 1)
plt.imshow(img_rgb)
plt.show()

# %%
import pandas as pd
file_xml = pd.read_xml('/content/stop_data.xml')
file_xml.head()
# Out:
#   stageType featureType  height  width  stageParams  featureParams  stageNum  \
# 0     BOOST        HAAR      24     24          NaN            NaN        20
#
#    stages  features
# 0     NaN       NaN
